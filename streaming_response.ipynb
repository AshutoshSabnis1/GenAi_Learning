# %%
# Stream- Line by line response from Groq LLMs
# Invoke = All answer at once
from dotenv import load_dotenv

# %%
from langchain_groq import ChatGroq
llm=ChatGroq(model="llama-3.3-70b-versatile", streaming=True)

# %%
question="Can you explain GenAi?"
response=llm.stream(question)

# %%
for chunk in response:
    print(chunk.content, end='', flush=True)
# Out:
# GenAI, also known as Generative Artificial Intelligence, refers to a type of artificial intelligence that can generate new, original content, such as text, images, music, or videos, based on patterns and structures learned from existing data. This technology has gained significant attention in recent years due to its potential to revolutionize various industries and aspects of our lives.
#
# Key characteristics of GenAI:
#
# 1. **Generative capabilities**: GenAI models can create new content that is similar in style, structure, and quality to the training data.
# 2. **Pattern recognition**: GenAI models learn patterns and relationships within the training data, allowing them to generate new content that is coherent and contextually relevant.
# 3. **Creativity**: GenAI models can produce novel and innovative content, often surprising users with their creativity and originality.
# ...
